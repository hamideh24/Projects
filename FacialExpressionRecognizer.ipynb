# %%
import cv2

# %%
from deepface import DeepFace

# %%
image = cv2.imread("/Users/wreckit/PycharmProjects/FacialExpressions/happyboy.jpeg")

# %%
import matplotlib.pyplot as plot

# %%
plot.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
predict = DeepFace.analyze(image)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.11it/s]

# %%
predict
# Out:
# {'emotion': {'angry': 0.013035575300089341,
#   'disgust': 0.0036701896188953355,
#   'fear': 0.0019203193945943051,
#   'happy': 99.66188661143461,
#   'sad': 0.07582996684356734,
#   'surprise': 0.00015106295641112197,
#   'neutral': 0.2435113185447618},
#  'dominant_emotion': 'happy',
#  'region': {'x': 352, 'y': 204, 'w': 505, 'h': 505},
#  'age': 25,
#  'gender': 'Woman',
#  'race': {'asian': 1.486971415579319,
#   'indian': 2.1782591938972473,
#   'black': 0.23385018575936556,
#   'white': 52.79473066329956,
#   'middle eastern': 23.402339220046997,
#   'latino hispanic': 19.90385353565216},
#  'dominant_race': 'white'}

# %%
type(predict)
# Out:
# dict

# %%
predict['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
##draw rectangle across face
g = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
##print(faceCascade.empty())

faces = faceCascade.detectMultiScale(g, 1.1, 4)

##Draw rectangle
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#USE putTEXT() for text on video

cv2.putText(image, predict['dominant_emotion'],
           (0,50),
           font, 1, 
           (0,0,255),
            1,
           cv2.LINE_4);

# %%
plot.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
image_2 = cv2.imread("/Users/wreckit/PycharmProjects/FacialExpressions/cryinggal.jpeg")

# %%
##draw rectangle across face
g = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY)
##print(faceCascade.empty())

faces = faceCascade.detectMultiScale(g, 1.1, 4)

##Draw rectangle
for (x, y, w, h) in faces:
    cv2.rectangle(image_2, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plot.imshow(cv2.cvtColor(image_2, cv2.COLOR_BGR2RGB))

# %%
predict_2 = DeepFace.analyze(image_2)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]

# %%
predict_2
# Out:
# {'emotion': {'angry': 2.6506374135523703e-11,
#   'disgust': 3.844673858965974e-23,
#   'fear': 6.940463208593428e-05,
#   'happy': 3.8821093006902174e-07,
#   'sad': 99.9998927116394,
#   'surprise': 1.5081592231864157e-16,
#   'neutral': 3.6092424693379144e-05},
#  'dominant_emotion': 'sad',
#  'region': {'x': 381, 'y': 263, 'w': 419, 'h': 419},
#  'age': 29,
#  'gender': 'Man',
#  'race': {'asian': 82.65345589241123,
#   'indian': 0.6035285430269565,
#   'black': 0.1387575491149753,
#   'white': 11.49626666285197,
#   'middle eastern': 1.7240905299240668,
#   'latino hispanic': 3.383906387323522},
#  'dominant_race': 'asian'}

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#USE putTEXT() for text on video

cv2.putText(image_2, predict_2['dominant_emotion'],
           (0,50),
           font, 1, 
           (0,0,255),
            5,
           cv2.LINE_4);

# %%
image_3 = cv2.imread("/Users/wreckit/PycharmProjects/FacialExpressions/scaredperson.jpeg")

# %%
##draw rectangle across face
g = cv2.cvtColor(image_3, cv2.COLOR_BGR2GRAY)
##print(faceCascade.empty())

faces = faceCascade.detectMultiScale(g, 1.1, 4)

##Draw rectangle
for (x, y, w, h) in faces:
    cv2.rectangle(image_3, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plot.imshow(cv2.cvtColor(image_3, cv2.COLOR_BGR2RGB))

# %%
predict_3 = DeepFace.analyze(image_3)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.68it/s]

# %%
predict_3
# Out:
# {'emotion': {'angry': 0.2635422395542264,
#   'disgust': 2.4249445118584845e-06,
#   'fear': 82.45189785957336,
#   'happy': 0.022878874733578414,
#   'sad': 0.012013222294626758,
#   'surprise': 17.24965125322342,
#   'neutral': 2.4054276082097203e-05},
#  'dominant_emotion': 'fear',
#  'region': {'x': 339, 'y': 72, 'w': 266, 'h': 266},
#  'age': 43,
#  'gender': 'Man',
#  'race': {'asian': 0.1439116490812124,
#   'indian': 1.9871618092463244,
#   'black': 0.07366357307980083,
#   'white': 51.89421154329639,
#   'middle eastern': 30.869253770201947,
#   'latino hispanic': 15.031791921640405},
#  'dominant_race': 'white'}

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#USE putTEXT() for text on video

cv2.putText(image_3, predict_3['dominant_emotion'],
           (0,50),
           font, 1, 
           (0,0,255),
            3,
           cv2.LINE_4);

# %%
##Real time video
import cv2

from deepface import DeepFace


face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

camera = cv2.VideoCapture(0)

if not camera.isOpened():
    raise IOError("Can't Open Camera")

    
while True:
    ret,frame = camera.read() #Read one image from a video
    
    result = DeepFace.analyze(frame, enforce_detection=False)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,0), 2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(frame, result['dominant_emotion'],
               (50,50),
               font, 3,
               (0,0,255),
               2,
               cv2.LINE_4)
        
    cv2.imshow("Demo Video", frame)

    if cv2.waitKey(1) and 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Action: race:  75%|███████▌  | 3/4 [00:00<00:00,  3.09it/s]
